# %% [markdown]
# Zakładanie git w komputerze:
# w bash
#
# sudo apt install git
#
# hasło: wojciech

# %% [markdown]
# ![obraz.png](attachment:obraz.png)

# %% [markdown]
# Utworzyć katalog gdzie ma być repozytorium
#
# - mkdir archiwum_git
# - cd -    zmiana katalogu
# - pwd -   pokazuje ścieżkę w której się znajduje
# - touch - tworzy pusty plik
# - du - pokazuje ile wazy folder
# - ls - pokazuje zawartosc

# %% [markdown]
# ![obraz.png](attachment:obraz.png)

# %% [markdown]
# Specjalne pliki w Linux
#
#  - cd
#         kropka . - aktualny katalog
#         2 kropki - cofa się

# %% [markdown]
# ## Tworzenie repozytorium GIT
#
# git init    - tworzenie pustego repozytorium
# ![obraz.png](attachment:obraz.png)

# %% [markdown]
# ## Dodaje wszystkie pliki z katalogu do repozytorium
# git add .  - dodaje do założonego archiwum wszystkie pliki i katalogi z katalogu w którym jestem
# git add

# %% [markdown]
# # Przeglądanie zawartości katalogu
# ls
#
# - zielone są to programy
# - niebieskie to katalogi
# ![obraz.png](attachment:obraz.png)

# %% [markdown]
# ![obraz.png](attachment:obraz.png)

# %% [markdown]
# # Utworzyłem konto na gitLab
# https://gitlab.com/

# %% [markdown]
# ![obraz.png](attachment:obraz.png)

# %% [markdown]
# Wchodzę na bash i wykonuje komendy:
# ![obraz.png](attachment:obraz.png)

# %% [markdown]
# Plik musi być w tym katalogu który założyłem w gitlab

# %% [markdown]
# git commit

# %% [markdown]
# ### git commit
#
# wyskakuje głupi edytor tekstowy - trzeba tam coś wpisać - opis projektu
# następnie trzeba wpisać
#
# ### git push
#
# i się zalogować
#
#     Username for 'https://gitlab.com': wtm695450085
#
#
#     Password for 'https://wtm695450085@gitlab.com': Ewa183311#

# %%
git push
