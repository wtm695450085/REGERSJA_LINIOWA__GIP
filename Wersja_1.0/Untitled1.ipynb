# %%
import pandas as pd

df1 = pd.read_csv('/media/wojciech/D6DE33C1DE339927/1/titanic_train.csv')
df2 = pd.read_csv('/media/wojciech/D6DE33C1DE339927/1/titanic_test.csv')

# %%
print(df1.shape)
df1.head(3)
# Out:
# (850, 15)
#    passenger_id  pclass                                               name  \
# 0          1216       3                                 Smyth, Miss. Julia
# 1           699       3                                    Cacic, Mr. Luka
# 2          1267       3  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
#
#       sex   age  sibsp  parch  ticket     fare cabin embarked boat  body  \
# 0  female   NaN      0      0  335432   7.7333   NaN        Q   13   NaN
# 1    male  38.0      0      0  315089   8.6625   NaN        S  NaN   NaN
# 2  female  30.0      1      1  345773  24.1500   NaN        S  NaN   NaN
#
#   home.dest  survived
# 0       NaN         1
# 1   Croatia         0
# 2       NaN         0

# %%
print(df2.shape)
df2.head(3)
# Out:
# (459, 14)
#    passenger_id  pclass                         name   sex   age  sibsp  \
# 0           295       1  Thayer, Mr. John Borland Jr  male  17.0      0
# 1          1150       3     Risien, Mr. Samuel Beard  male   NaN      0
# 2            89       1       Davidson, Mr. Thornton  male  31.0      1
#
#    parch      ticket      fare cabin embarked boat  body      home.dest
# 0      2       17421  110.8833   C70        C    B   NaN  Haverford, PA
# 1      0      364498   14.5000   NaN        S  NaN   NaN            NaN
# 2      0  F.C. 12750   52.0000   B71        S  NaN   NaN   Montreal, PQ

# %%
df = df1.append([df2])
# Out:
# /home/wojciech/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %% [raw]
# df = pd.concat([df1,df2], sort=True).sort_values('passenger_id')

# %%
print(df.shape)
df.head(13)
# Out:
# (1309, 15)
#      age boat   body cabin embarked      fare                  home.dest  \
# 0    NaN   13    NaN   NaN        Q    7.7333                        NaN
# 1   38.0  NaN    NaN   NaN        S    8.6625                    Croatia
# 2   30.0  NaN    NaN   NaN        S   24.1500                        NaN
# 3   54.0    4    NaN   NaN        S   23.0000       Cornwall / Akron, OH
# 4   40.0  NaN    NaN   NaN        S   13.0000   Barre, Co Washington, VT
# 5   28.0  NaN  173.0   NaN        S   22.5250                        NaN
# 6   19.0  NaN    NaN   NaN        S    0.0000                        NaN
# 7   30.0   10    NaN   NaN        S   13.0000   Finland / Washington, DC
# 8   22.0    C    NaN   NaN        S    7.7750                        NaN
# 9   21.0  NaN    NaN   NaN        S    9.8250                        NaN
# 10  27.0  NaN    NaN   C82        C  211.5000            Elkins Park, PA
# 11  60.0    8    NaN   D15        C   76.2917           Philadelphia, PA
# ...

# %%
df.to_csv('/media/wojciech/D6DE33C1DE339927/1/titanic.csv')
